# %% [markdown]
# # Chargeback FCA Add-on
# #### **Fabric Cost Analysis** and **Fabric Unified Admin Monitoring** — better together
#
# Allocate Microsoft Fabric capacity costs to individual workspaces based on **actual CU consumption**.
# Bridges **FCA** (Azure billing in FOCUS format) with **FUAM** (capacity metrics + workspace metadata).
#
# Supports **on-demand (PAYG)** and **reserved capacity (RI/Commitment-Based)** pricing.
#
# ---
#
# ### What this notebook does
# 1. Creates **3 OneLake shortcuts** in the FCA Lakehouse pointing to FUAM tables
# 2. Creates **4 SQL views** in the FCA SQL analytics endpoint:
#
# | View | Purpose |
# |------|---------|
# | `v_CapacityCostPeriod` | Daily amortized cost per capacity (EffectiveCost + ListCost) |
# | `v_WorkspacesCUConsumption` | CU share % per workspace per day (F + P SKUs) |
# | `v_FabricCostSplitByWorkspace` | **Final chargeback** — cost × CU% per workspace |
# | `v_ReservationSavingsSummary` | Reservation ROI: savings vs on-demand per billing period |
#
# No refresh required — shortcuts are live pointers, views compute on read.
#
# ---
#
# ### Setup
# 1. Edit the **Parameters** cell below: set your FUAM and FCA lakehouse / workspace names
# 2. Run all cells in order

# %%
# %pip install semantic-link-labs

# %%
# =============================================================================
# PARAMETERS — update before running
# =============================================================================
# Source: FUAM Lakehouse (where CU metrics and workspace metadata live)
source_lakehouse  = "FUAM_Lakehouse"
source_workspace  = "FUAM"

# Destination: FCA Lakehouse (where billing data + shortcuts + views go)
destination_lakehouse = "FCA"
destination_workspace = "FCA"

# Schema used for shortcuts and views (default: dbo)
schema_shortcut_destination = "dbo"

# --- Optional: multi-environment support ---
# Uncomment and set the target environment if deploying to Dev / UAT / Prod.
# environment = "prod"   # one of: dev | uat | prod
# destination_workspace = f"FCA-{environment}"

# --- Optional: budget alert threshold (Phase 3.1) ---
# Alert is triggered in the validation cell if any workspace exceeds this
# daily cost threshold.
BUDGET_ALERT_DAILY_USD = 50.0   # set to None to disable

# %%
# Import Sempy for Shortcut Creation
import json 
import notebookutils 
import sempy.fabric as fabric 
from sempy.fabric.exceptions import FabricHTTPException, WorkspaceNotFoundException 
import sempy_labs.lakehouse as lake
import sempy_labs as labs

# %%
## List of tables for Shortcut creation
# capacities  // capacity_metrics_by_item_kind_by_day // workspaces
tables_shortcut = ["capacities","capacity_metrics_by_item_kind_by_day","workspaces"]
prefix_shortcut = "FUAM_"

# %%
# Function to check for existing shortcuts
def shortcut_exists(destination_lakehouse, destination_workspace, shortcut_name):
    existing_shortcuts = lake.get_lakehouse_tables(
        lakehouse=destination_lakehouse,
        workspace=destination_workspace
    )
    return shortcut_name in existing_shortcuts['Table Name'].values

for table in tables_shortcut:
    shortcut_name = prefix_shortcut + table
    destination_path = destination_path="Tables/" + schema_shortcut_destination
    # Check if the shortcut already exists
    if shortcut_exists(destination_lakehouse, destination_workspace, shortcut_name):
        try:
            # Delete the existing shortcut
            lake.delete_shortcut(
                shortcut_name=shortcut_name,
                lakehouse=destination_lakehouse,
                workspace=destination_workspace
            )
            print(f"🟢 The shortcut '{shortcut_name}' in '{destination_workspace}' has been deleted.")
        except Exception as e:
            print(f"🔴 Failed to delete existing shortcut '{shortcut_name}'. Error: {e}")
            continue  # Skip to the next shortcut if delete fails
        
    # Create a new shortcut
    try:
        lake.create_shortcut_onelake(table_name=table, source_lakehouse=source_lakehouse, 
        source_workspace=source_workspace, destination_lakehouse=destination_lakehouse, 
        destination_workspace=destination_workspace, 
        destination_path=destination_path, shortcut_name=shortcut_name)
        print(f"🟢 Shortcut created successfully for: '{shortcut_name}'")
    except Exception as e:
        print(f"🔴 Failed to create shortcut for '{shortcut_name}'. Error: {e}")

print("All shortcuts processed successfully.")

# %%
#Shorcut verification
df = lake.list_shortcuts(lakehouse=destination_lakehouse, workspace=destination_workspace)
df

# %%
# ---------------------------------------------------------------------------
# Deploy all SQL views from chargeback_views.sql (single-source of truth)
#
# HOW TO USE:
#   1. Upload chargeback_views.sql to the Files/ section of the destination lakehouse
#      (Fabric UI → Lakehouse → Files → Upload, or drag-and-drop)
#   2. Run this cell — every CREATE OR ALTER VIEW batch will be deployed in order.
#
# The file is split on the T-SQL GO batch separator and each view is executed
# individually so that a failure in one view surfaces clearly with its name.
# ---------------------------------------------------------------------------
import re
import os

# Locate the SQL file — OneLake-mounted Files/ first, then notebook-local fallback
_candidates = [
    "/lakehouse/default/Files/chargeback_views.sql",  # Fabric lakehouse mount
    os.path.join(os.getcwd(), "chargeback_views.sql"),  # local / repo root
]
_sql_path = next((p for p in _candidates if os.path.isfile(p)), None)

if _sql_path is None:
    raise FileNotFoundError(
        "chargeback_views.sql not found.\n"
        "Upload it to the lakehouse Files/ section, or place it next to the notebook."
    )

print(f"📂 Reading views from: {_sql_path}")

with open(_sql_path, "r", encoding="utf-8") as _f:
    _sql_content = _f.read()

# Split on GO batch separator; keep only CREATE OR ALTER VIEW batches
_batches = re.split(r"^\s*GO\s*$", _sql_content, flags=re.MULTILINE)
_view_batches = [
    b.strip() for b in _batches
    if re.search(r"CREATE\s+OR\s+ALTER\s+VIEW", b, re.IGNORECASE)
]

print(f"📋 Found {len(_view_batches)} view(s) to deploy\n")

with labs.ConnectLakehouse(lakehouse=destination_lakehouse, workspace=destination_workspace) as _sql:
    for _batch in _view_batches:
        _m = re.search(
            r"CREATE\s+OR\s+ALTER\s+VIEW\s+\[?dbo\]?\.\[?(\w+)\]?",
            _batch, re.IGNORECASE
        )
        _view_name = _m.group(1) if _m else "unknown_view"
        try:
            _sql.query(_batch)
            print(f"  ✅  {_view_name}")
        except Exception as _exc:
            print(f"  ❌  {_view_name}: {_exc}")
            raise

print("\n✅ All SQL views deployed successfully.")

# %%
# =============================================================================
# VALIDATION  (Phase 4.2)
# Run after all views are created to confirm setup is correct and flag anomalies.
# =============================================================================

import warnings

with labs.ConnectLakehouse(lakehouse=destination_lakehouse, workspace=destination_workspace) as sql:

    # --- 1. Preview chargeback output ---
    print("── Chargeback preview (top 20 rows) ─────────────────────────")
    result = sql.query("""
        SELECT TOP 20
            CapacityName,
            WorkspaceName,
            ChargePeriod,
            PricingCategory,
            CostCategory,
            ROUND(TotalCostCapacity, 4)          AS TotalCostCapacity,
            ROUND(TotalCostWorkspace, 4)          AS TotalCostWorkspace,
            ROUND(ReservationSavingsWorkspace, 4) AS ReservationSavings,
            ROUND(CUSharePercent * 100, 2)        AS CUSharePct
        FROM [dbo].[v_FabricCostSplitByWorkspace]
        ORDER BY ChargePeriod DESC, TotalCostWorkspace DESC
    """)
    display(result)

    # --- 2. Row-count sanity check ---
    print("\n── Row counts per view ───────────────────────────────────────")
    counts = sql.query("""
        SELECT 'v_FabricCostSplitByWorkspace'  AS ViewName, COUNT(*) AS Rows FROM [dbo].[v_FabricCostSplitByWorkspace]  UNION ALL
        SELECT 'v_ItemKindCostByWorkspace',                  COUNT(*) FROM [dbo].[v_ItemKindCostByWorkspace]             UNION ALL
        SELECT 'v_ChargebackByDepartment',                   COUNT(*) FROM [dbo].[v_ChargebackByDepartment]              UNION ALL
        SELECT 'v_ReservationSavingsSummary',                COUNT(*) FROM [dbo].[v_ReservationSavingsSummary]           UNION ALL
        SELECT 'v_UnusedReservationHours',                   COUNT(*) FROM [dbo].[v_UnusedReservationHours]
    """)
    display(counts)

    # --- 3. Missing-day detection ---
    print("\n── Missing charge days (gaps in the last 30 days) ───────────")
    gaps = sql.query("""
        SELECT TOP 10
            CapacityName,
            MIN(ChargePeriod) AS EarliestDay,
            MAX(ChargePeriod) AS LatestDay,
            COUNT(DISTINCT ChargePeriod) AS DaysCovered
        FROM [dbo].[v_FabricCostSplitByWorkspace]
        WHERE ChargePeriod >= DATEADD(day, -30, GETDATE())
        GROUP BY CapacityName
        ORDER BY DaysCovered ASC
    """)
    display(gaps)

    # --- 4. Budget alert check  (Phase 3.1) ---
    if BUDGET_ALERT_DAILY_USD is not None:
        print(f"\n── Budget alerts (daily threshold: ${BUDGET_ALERT_DAILY_USD}) ──")
        alerts = sql.query(f"""
            SELECT
                WorkspaceName,
                ChargePeriod,
                ROUND(SUM(TotalCostWorkspace), 4) AS DailyCost
            FROM [dbo].[v_FabricCostSplitByWorkspace]
            GROUP BY WorkspaceName, ChargePeriod
            HAVING SUM(TotalCostWorkspace) > {BUDGET_ALERT_DAILY_USD}
            ORDER BY DailyCost DESC
        """)
        if len(alerts) > 0:
            warnings.warn(f"⚠️  {len(alerts)} workspace/day combinations exceeded the ${BUDGET_ALERT_DAILY_USD} budget threshold.")
            display(alerts)
        else:
            print(f"✅ No workspace exceeded ${BUDGET_ALERT_DAILY_USD}/day.")

    # --- 5. Department mapping coverage ---
    print("\n── Department mapping coverage ───────────────────────────────")
    coverage = sql.query("""
        SELECT Department, CostCenter, COUNT(DISTINCT WorkspaceId) AS Workspaces,
               ROUND(SUM(TotalCostWorkspace), 2) AS TotalCost
        FROM [dbo].[v_ChargebackByDepartment]
        GROUP BY Department, CostCenter
        ORDER BY TotalCost DESC
    """)
    display(coverage)
